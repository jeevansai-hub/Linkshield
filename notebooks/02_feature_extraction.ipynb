# %% [markdown]
# # Notebook 02: Static Feature Extraction Pipeline
#
# **Project**: LinkSentinel (`LinkShield`)
# **Objective**: Extract static lexical and structural URL features using `src.features.extract_features`.

# %%
import sys
sys.path.append('..')
from src.features.extract_features import URLLexicalFeatureExtractor

extractor = URLLexicalFeatureExtractor()
sample_features = extractor.extract('http://login.paypal.account-update.com/verify')
print("Extracted Features:", sample_features)
