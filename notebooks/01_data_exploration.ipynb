# %% [markdown]
# # Notebook 01: Exploratory Data Analysis (EDA)
#
# **Project**: LinkSentinel (`LinkShield`)
# **Objective**: Inspect raw URL dataset distributions, check label balance, and analyze raw string properties.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load raw dataset immutably
# df = pd.read_csv('../data/raw/dataset.csv')
print("Notebook 01 ready for EDA.")
