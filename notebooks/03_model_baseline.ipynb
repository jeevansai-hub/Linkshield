# %% [markdown]
# # Notebook 03: Baseline & Ensemble Model Training
#
# **Project**: LinkSentinel (`LinkShield`)
# **Objective**: Train Logistic Regression baseline and evaluate Random Forest / XGBoost classifiers with `random_state=42`.

# %%
import sys
sys.path.append('..')
from src.models.train_evaluate import ModelPipeline

pipeline = ModelPipeline(model_type='logistic_regression')
print("Model pipeline initialized:", pipeline.model_type)
